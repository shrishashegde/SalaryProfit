# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('Position_Salaries.csv')
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# ## Training the Linear Regression model on the whole dataset

# %%
from sklearn.linear_model import LinearRegression
linearRegressor = LinearRegression()
linearRegressor.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ## Training the Polynomial Regression model on the whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures
polReg = PolynomialFeatures(3)
X_poly = polReg.fit_transform(X)
polyRegressor = LinearRegression()
polyRegressor.fit(X_poly, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ## Visualising the Linear Regression results

# %%
plt.scatter(X, y)
plt.plot(X, linearRegressor.predict(X), color = 'r')

# %% [markdown]
# ## Visualising the Polynomial Regression results

# %%
plt.scatter(X, y)
plt.plot(X, polyRegressor.predict(X_poly), color = 'r')

# %% [markdown]
# ## Visualising the Polynomial Regression results (for higher resolution and smoother curve)

# %% [markdown]
# ## Predicting a new result with Linear Regression

# %%
print(linearRegressor.predict([[6.5]]))
# Out:
# [330378.78787879]

# %% [markdown]
# ## Predicting a new result with Polynomial Regression

# %%
print(polyRegressor.predict(polReg.fit_transform([[6.5]])))
# Out:
# [133259.46969697]
